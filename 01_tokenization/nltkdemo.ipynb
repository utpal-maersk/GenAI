# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
nltk.download('subjectivity')
nltk.download('movie_reviews')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/Utpal.Gohain/nltk_data...
# [nltk_data] Downloading package subjectivity to
# [nltk_data]     /Users/Utpal.Gohain/nltk_data...
# [nltk_data]   Unzipping corpora/subjectivity.zip.
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     /Users/Utpal.Gohain/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# True

# %%
sia=SentimentIntensityAnalyzer()
sia.polarity_scores('I am a human')
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
sia.polarity_scores('Horrible !!')
# Out:
# {'neg': 0.803, 'neu': 0.197, 'pos': 0.0, 'compound': -0.6229}

# %%
sia.polarity_scores('This company is done incredibly well !!')
# Out:
# {'neg': 0.0, 'neu': 0.668, 'pos': 0.332, 'compound': 0.4547}

# %%
while True:
    next_msg=input("Message: ")
    scores=sia.polarity_scores(next_msg)
    compound=scores['compound']
    if compound >0:
        print('Positive Comment !!')
    elif compound < -0.1:
        print('Negative Comment !!')
    else:
        print('Neutral')
# Out:
# Positive sentiment !!
# Negative
# Negative
# Negative
# Negative
# Negative
